# %% [markdown]
# # Physical Activity Analysis

# %% [markdown]
# Dataset used is the **Physical Activity and Transit Survey (PAT)**. It is a survey conducted by the NYC Department of Health and Mental Hygiene in 2010-2011 consisting of 2 major parts: a **telephone survey of physical activity and health** (N=3811) and a **weeklong accelerometer device study** (N=679) . Note: A sub-sample of participants of the phone survey participated in the accelerometer study.
#
# [Link to survey](https://www.nyc.gov/site/doh/data/data-sets/physical-activity-and-transit-survey-public-use-data.page)

# %%
import numpy as np
import pandas as pd

# %%
# Adjust settings to display all rows and columns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import sas7bdat_converter

file_dicts = [
  {
    'sas7bdat_file': '/Users/alex/Downloads/accl_public.sas7bdat',
    'export_file': '/Users/alex/PythonTest/accl_public.csv',
  },
    {
    'sas7bdat_file': '/Users/alex/Downloads/minutes_file.sas7bdat',
    'export_file': '/Users/alex/PythonTest/minutes_file.csv',
  }
]
sas7bdat_converter.batch_to_csv(file_dicts)

# %%
#Missing values:
    
df.isna().sum().sort_values(ascending = False)[:10]
# Out:
# stairs9        24
# Tot_sed        12
# Mental          8
# Energy          6
# bmicat4         5
# cholesterol     4
# Sleep           3
# Phys_health     3
# screentime      2
# Arthritis       2
# dtype: int64

# %% [markdown]
# We will not be considering the features with half of the responses missing.

# %%
len(df)
# Out:
# 516

# %%
survey_df = pd.read_csv('pat_w1w2.csv')
weekly_df = pd.read_csv('accl_public.csv')

# %%
# Load data (survey Q&A and weekly accelerometer data) 


def create_df(survey_df,weekly_df):

        #select columns to leave in the dataframes
        survey_df = survey_df.loc[:,['PATCID','agegroup','dem3','bmicat4','status1','chronic1','chronic2','chronic3','chronic4',\
                                      'chronic5','chronic6','status2','status3','tobacco1','alcohol1',\
                                      'status4','status5','status6','gpaqsedall','gpaq18pa','gpaq8totmin',\
                                      'gpaqadd1_weekday','habits1','habits2',\
                                      'habits5','habits7','stairs9','MVPA']]

        weekly_df = weekly_df.loc[:,['patcid','Valid_Days','MVPA_bout','counts_avg','Sed_avg','Light_avg','moderate_avg','vigorous_avg']]


        # Set index to unique participant identifier
        survey_df = survey_df.astype({'PATCID': 'int32'})
        survey_df.set_index('PATCID',inplace=True)

        weekly_df = weekly_df.astype({'patcid': 'int32'})
        weekly_df.set_index('patcid',inplace=True)

        # Merge dataframes to include only those who participated in both the phone survey and acclerometer study
        l2 = weekly_df.index.unique().tolist()
        l1 = survey_df.index.unique().tolist()
        common_list = list(set(l2).intersection(l1))
        survey_df_ref = survey_df[survey_df.index.isin(common_list)]

        df = pd.concat([survey_df_ref,weekly_df],axis = 1)

        # For the merged datafrme, df, leave only the people who wore the accelerometer at least 6 days of the week
        df = df.loc[(df.Valid_Days == 7) | (df.Valid_Days == 6)]#.loc[:,['Valid_Days','MVPA_bout','PAGA08_4','counts_avg','Sed_avg']]
        weekly_df.drop('Valid_Days',axis = 1)

        # Rename columns
        df.rename(columns={"agegroup": "Age", "dem3": "Gender","status1": "Health",'status2':'Phys_health', "status3": "Mental",\
                          "status4": "Sleep", "status5": "Energy","status6": "Impairment", "chronic1": "Hypertension",\
                          "chronic2": "cholesterol",'chronic3':'Diabetes','chronic4':'Asthma','chronic5':'Arthritis',\
                          "chronic6": "Depression","status6": "Impairment", "gpaqsedall": "Tot_sed","habits1": "Exer_routine",\
                          "habits3_walking": "Walking", "habits3_wtlift": "Weightlift",\
                          "habits3_run": "Running", "habits3_tread": "Treadmill","habits3_aerob": "Aerobics", "habits3_bike": "Biking,",\
                          "habits5": "Phys_Activity", "habits7": "Diet",'transport7mpd':'commute','gpaqadd1_weekday':'screentime',\
                          "gpaq18pa":"phys7",'gpaq8totmin':'chores','habits2':'gym_member'},
              inplace= True)
        
        return(df)

# %%
df = create_df(survey_df,weekly_df)

# %%
# Display correlations between all the features in the dataframe
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ed5cd_row0_col0, #T_ed5cd_row1_col1, #T_ed5cd_row2_col2, #T_ed5cd_row3_col3, #T_ed5cd_row4_col4, #T_ed5cd_row5_col5, #T_ed5cd_row6_col6, #T_ed5cd_row7_col7, #T_ed5cd_row8_col8, #T_ed5cd_row9_col9, #T_ed5cd_row10_col10, #T_ed5cd_row11_col11, #T_ed5cd_row12_col12, #T_ed5cd_row13_col13, #T_ed5cd_row14_col14, #T_ed5cd_row15_col15, #T_ed5cd_row16_col16, #T_ed5cd_row17_col17, #T_ed5cd_row18_col18, #T_ed5cd_row19_col19, #T_ed5cd_row20_col20, #T_ed5cd_row21_col21, #T_ed5cd_row22_col22, #T_ed5cd_row23_col23, #T_ed5cd_row24_col24, #T_ed5cd_row25_col25, #T_ed5cd_row26_col26, #T_ed5cd_row27_col27, #T_ed5cd_row28_col28, #T_ed5cd_row29_col29, #T_ed5cd_row30_col30, #T_ed5cd_row31_col31, #T_ed5cd_row32_col32, #T_ed5cd_row33_col33 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col1, #T_ed5cd_row6_col21, #T_ed5cd_row9_col17, #T_ed5cd_row12_col26, #T_ed5cd_row13_col28, #T_ed5cd_row21_col19, #T_ed5cd_row22_col25, #T_ed5cd_row25_col18, #T_ed5cd_row29_col17, #T_ed5cd_row30_col2, #T_ed5cd_row30_col13, #T_ed5cd_row31_col33, #T_ed5cd_row33_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col2, #T_ed5cd_row1_col17, #T_ed5cd_row14_col0, #T_ed5cd_row15_col12, #T_ed5cd_row27_col17, #T_ed5cd_row30_col10, #T_ed5cd_row32_col14, #T_ed5cd_row33_col26 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col3, #T_ed5cd_row0_col30, #T_ed5cd_row4_col15, #T_ed5cd_row4_col16, #T_ed5cd_row16_col9, #T_ed5cd_row21_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_ed5cd_row0_col4, #T_ed5cd_row0_col6, #T_ed5cd_row0_col8, #T_ed5cd_row0_col19, #T_ed5cd_row0_col32, #T_ed5cd_row1_col25, #T_ed5cd_row3_col5, #T_ed5cd_row3_col6, #T_ed5cd_row3_col7, #T_ed5cd_row3_col15, #T_ed5cd_row3_col16, #T_ed5cd_row4_col0, #T_ed5cd_row8_col2, #T_ed5cd_row9_col11, #T_ed5cd_row11_col9, #T_ed5cd_row12_col24, #T_ed5cd_row12_col27, #T_ed5cd_row15_col3, #T_ed5cd_row15_col14, #T_ed5cd_row15_col21, #T_ed5cd_row15_col24, #T_ed5cd_row16_col10, #T_ed5cd_row18_col28, #T_ed5cd_row18_col33, #T_ed5cd_row22_col27, #T_ed5cd_row23_col26, #T_ed5cd_row24_col12, #T_ed5cd_row28_col18, #T_ed5cd_row29_col13, #T_ed5cd_row29_col20, #T_ed5cd_row29_col23, #T_ed5cd_row30_col29, #T_ed5cd_row30_col31, #T_ed5cd_row31_col17, #T_ed5cd_row31_col30, #T_ed5cd_row32_col1, #T_ed5cd_row32_col13, #T_ed5cd_row33_col21, #T_ed5cd_row33_col22 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col5, #T_ed5cd_row0_col27, #T_ed5cd_row8_col18, #T_ed5cd_row9_col1, #T_ed5cd_row14_col12, #T_ed5cd_row14_col15, #T_ed5cd_row18_col19, #T_ed5cd_row26_col18 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col7, #T_ed5cd_row8_col19, #T_ed5cd_row9_col22, #T_ed5cd_row14_col19, #T_ed5cd_row18_col6, #T_ed5cd_row19_col2, #T_ed5cd_row19_col27, #T_ed5cd_row21_col13, #T_ed5cd_row24_col16, #T_ed5cd_row27_col24, #T_ed5cd_row28_col0, #T_ed5cd_row29_col3, #T_ed5cd_row30_col27, #T_ed5cd_row31_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col9, #T_ed5cd_row0_col11, #T_ed5cd_row2_col21, #T_ed5cd_row6_col11, #T_ed5cd_row7_col12, #T_ed5cd_row7_col28, #T_ed5cd_row8_col6, #T_ed5cd_row13_col0, #T_ed5cd_row14_col23, #T_ed5cd_row15_col28, #T_ed5cd_row25_col26, #T_ed5cd_row27_col6, #T_ed5cd_row32_col5, #T_ed5cd_row33_col11, #T_ed5cd_row33_col17 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ed5cd_row0_col10, #T_ed5cd_row11_col31, #T_ed5cd_row12_col16, #T_ed5cd_row18_col0, #T_ed5cd_row18_col23 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ed5cd_row0_col12, #T_ed5cd_row7_col26, #T_ed5cd_row11_col1, #T_ed5cd_row17_col29, #T_ed5cd_row22_col29, #T_ed5cd_row23_col8, #T_ed5cd_row23_col9, #T_ed5cd_row24_col9, #T_ed5cd_row30_col5, #T_ed5cd_row31_col7 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col13, #T_ed5cd_row0_col21, #T_ed5cd_row4_col13, #T_ed5cd_row4_col23, #T_ed5cd_row5_col23, #T_ed5cd_row8_col22, #T_ed5cd_row9_col27, #T_ed5cd_row18_col26, #T_ed5cd_row21_col7, #T_ed5cd_row21_col32, #T_ed5cd_row26_col2, #T_ed5cd_row27_col12, #T_ed5cd_row30_col24 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col14, #T_ed5cd_row8_col14, #T_ed5cd_row9_col26, #T_ed5cd_row12_col6, #T_ed5cd_row13_col12, #T_ed5cd_row14_col8, #T_ed5cd_row14_col32, #T_ed5cd_row17_col2, #T_ed5cd_row20_col31, #T_ed5cd_row21_col8, #T_ed5cd_row25_col12, #T_ed5cd_row28_col14, #T_ed5cd_row28_col17, #T_ed5cd_row31_col24 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col15, #T_ed5cd_row2_col9, #T_ed5cd_row10_col30, #T_ed5cd_row13_col15, #T_ed5cd_row18_col14, #T_ed5cd_row22_col15, #T_ed5cd_row28_col26, #T_ed5cd_row31_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_ed5cd_row0_col16, #T_ed5cd_row1_col5, #T_ed5cd_row1_col28, #T_ed5cd_row6_col24, #T_ed5cd_row8_col3, #T_ed5cd_row9_col3, #T_ed5cd_row12_col17, #T_ed5cd_row13_col32, #T_ed5cd_row14_col28, #T_ed5cd_row20_col8, #T_ed5cd_row31_col27, #T_ed5cd_row33_col25 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col17, #T_ed5cd_row1_col4, #T_ed5cd_row1_col18, #T_ed5cd_row2_col10, #T_ed5cd_row3_col17, #T_ed5cd_row3_col31, #T_ed5cd_row4_col7, #T_ed5cd_row4_col33, #T_ed5cd_row6_col1, #T_ed5cd_row9_col0, #T_ed5cd_row9_col32, #T_ed5cd_row11_col0, #T_ed5cd_row11_col32, #T_ed5cd_row12_col8, #T_ed5cd_row20_col22, #T_ed5cd_row29_col7, #T_ed5cd_row29_col14, #T_ed5cd_row30_col20, #T_ed5cd_row32_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ed5cd_row0_col18, #T_ed5cd_row2_col30, #T_ed5cd_row3_col21, #T_ed5cd_row5_col32, #T_ed5cd_row7_col32, #T_ed5cd_row8_col5, #T_ed5cd_row9_col4, #T_ed5cd_row12_col31, #T_ed5cd_row15_col5, #T_ed5cd_row17_col14, #T_ed5cd_row18_col24, #T_ed5cd_row22_col11, #T_ed5cd_row23_col14, #T_ed5cd_row25_col30, #T_ed5cd_row28_col11, #T_ed5cd_row31_col26, #T_ed5cd_row33_col31 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ed5cd_row0_col20, #T_ed5cd_row10_col20, #T_ed5cd_row16_col5, #T_ed5cd_row16_col6, #T_ed5cd_row16_col26, #T_ed5cd_row18_col15, #T_ed5cd_row20_col15, #T_ed5cd_row26_col3, #T_ed5cd_row28_col6, #T_ed5cd_row28_col7, #T_ed5cd_row28_col12 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ed5cd_row0_col22, #T_ed5cd_row5_col12, #T_ed5cd_row10_col1, #T_ed5cd_row12_col3, #T_ed5cd_row18_col1, #T_ed5cd_row18_col17, #T_ed5cd_row21_col4, #T_ed5cd_row22_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col23, #T_ed5cd_row6_col10, #T_ed5cd_row12_col5, #T_ed5cd_row18_col2, #T_ed5cd_row19_col22, #T_ed5cd_row21_col0, #T_ed5cd_row22_col14, #T_ed5cd_row27_col10, #T_ed5cd_row33_col5, #T_ed5cd_row33_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col24, #T_ed5cd_row6_col2, #T_ed5cd_row8_col1, #T_ed5cd_row14_col7, #T_ed5cd_row18_col12, #T_ed5cd_row19_col13, #T_ed5cd_row23_col32, #T_ed5cd_row24_col19, #T_ed5cd_row32_col22 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col25, #T_ed5cd_row20_col25 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col26, #T_ed5cd_row3_col12, #T_ed5cd_row8_col10, #T_ed5cd_row9_col21, #T_ed5cd_row9_col24, #T_ed5cd_row16_col18, #T_ed5cd_row17_col26, #T_ed5cd_row20_col19, #T_ed5cd_row21_col27, #T_ed5cd_row21_col28, #T_ed5cd_row32_col2, #T_ed5cd_row32_col20 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col28, #T_ed5cd_row3_col8, #T_ed5cd_row7_col19, #T_ed5cd_row12_col21, #T_ed5cd_row15_col11, #T_ed5cd_row24_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col29, #T_ed5cd_row12_col22, #T_ed5cd_row13_col19, #T_ed5cd_row16_col2, #T_ed5cd_row18_col25, #T_ed5cd_row28_col13, #T_ed5cd_row32_col23 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ed5cd_row0_col31, #T_ed5cd_row1_col9, #T_ed5cd_row1_col16, #T_ed5cd_row2_col18, #T_ed5cd_row6_col14, #T_ed5cd_row7_col5, #T_ed5cd_row14_col18, #T_ed5cd_row15_col0, #T_ed5cd_row25_col3, #T_ed5cd_row25_col6, #T_ed5cd_row27_col29 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ed5cd_row0_col33, #T_ed5cd_row8_col0, #T_ed5cd_row10_col27, #T_ed5cd_row16_col21, #T_ed5c

# %% [markdown]
#  <font size="3"> There are a few interesting insights gained from this correlation chart: </font>
#
# *Note: Because the scales/ranges were different for each question, a negative number does not mean negative correlation.*
#
# - Participants who had more average daily accelerometer activity counts tended to have less Hypertension (corr. 0.22) and arthritis (corr. 0.22).
#
# - Participants with more screentime tended to registed less activity on the accelerometer. They reported to be more sedentary (corr. 0.23), have worse diet (corr. 0.2), and have higher BMI (0.19).
#
# - Participants with higher Body Mass Indexes are more likely to have arthritis (corr. -0.2)
#
# - Participants who reported feeling the most healthy also reported being physically active (corr. 0.32) and good diet (corr. 0.37). Unsurprisingly, these individuals also had chronic physical conditions and depression.
#
# - Participants with poor mental health had worse sleep (corr. 0.39), had less energy (significantly) (corr. -0.36) were less physically active (corr. 0.19), and had worse diets (corr. 0.17)
#
# - Tobacco users had worse diets (corr. 	-0.21) and were more depressed (corr. 0.23)
